# %%
import urllib.request
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.persianlanguageonline.com/learn/hello'
html_doc = requests.get(url).content
soup = BeautifulSoup(html_doc, 'html.parser')
mydivs = soup.findAll("td", {"class": "Listen"})

# %%
mydivs
# Out:
# [<td class="Listen" style="border-right: none; border-right-width: 0; border-right-color: #fff;">
#  <script type="text/javascript">
#          jQuery(document).ready(function () {
#          $(".trigger-audio-930").click(function () {
#          $("#load-into-me-930").load("https://www.persianlanguageonline.com/wp-content/themes/persianlanguage/GlosAudio.php?id=930", function (response, status, xhr) {
#          if (status == "Failed") {
#          console.log("Failed");
#          } else if (status == "success") {
#          var myCirclePlayer = new CirclePlayer("#audio_jplayer_3_930",
#          {
#          mp3: "https://www.persianlanguageonline.com/wp-content/uploads/2019/08/salam.mp3"
#          }, {
#          cssSelectorAncestor: "#cp_container_3_930",
#                  swfPath: "https://www.persianlanguageonline.com/themes/persian/javascript/",
#                  supplied: "mp3"
#          });
#          $(".trigger-audio-930").next().removeClass('hide');
# ...

# %%
print('Beginning file download with urllib2...')

url = 'https://www.persianlanguageonline.com/wp-content/uploads/2019/08/salam.mp3'
urllib.request.urlretrieve(url, 'C:/Users/gnzak/Downloads/salam.mp3')
